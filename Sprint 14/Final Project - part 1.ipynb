# %% [markdown]
# Dividir las tareas del proyecto en pasos es una etapa obligatoria que te aportará 1 SP. Al elaborar un plan claro para abordar la tarea y obtener la aprobación del líder de tu equipo, ahorrarás tiempo y reducirás el número de revisiones que tendrás que hacer.
#
# Completa la tarea de descomposición en Jupyter Notebook. Utiliza Markdown para que la estructura y la presentación del documento sean ordenadas.
#
# El líder de tu equipo podría simplemente aceptar la descomposición, pero también podría pedirte que la mejores o hacerte preguntas. Recibirás sus comentarios en celdas separadas de tu documento dentro de las 24 horas posteriores a la entrega.

# %%
#Seleccionamos las bibliotecas que vamos a utilizar
import pandas as pd

# %%
#Importamos los datasets
operators= pd.read_csv('dataset/telecom_dataset_us.csv')
clients= pd.read_csv('dataset/telecom_clients_us.csv')

# %%
# Out:
# 2
